# %% [markdown]
# ##Estadistica aplicada
# Sesión 5 - 16 de agosto
#
# Susana Yareli Lino Resendiz 1986245
# Grupo41

# %%
#repaso rapido
#1. llamar las librerias a utilizar
import pandas as pd

# %%
calificaciones = pd.read_csv("https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/Calificaciones.csv")

# %%
#Vamos a elegir todas las columnas menos id
calificaciones = calificaciones.loc[:,calificaciones.columns!='Id']

# %%
#Renombrar
calificaciones = calificaciones.rename(columns={'Calficación Final':'CaliFinal'})
calificaciones.head()
# Out:
#     Nombre   Apellido  CaliFinal
# 0  ANTONIO     GARCIA         73
# 1   MANUEL  FERNANDEZ         19
# 2     JOSE   GONZALEZ         38
# 3    DAVID      PEREZ         14
# 4     JUAN      LOPEZ         99

# %%
#Promedio del grupo
calificaciones['CaliFinal'].mean()
# Out:
# 52.0

# %%
calificaciones['situacion']=np.where(calificaciones['CaliFinal'] >= 70, 'Aprobado','Reprobado')
calificaciones.head()
# Out:
#     Nombre   Apellido  CaliFinal  situacion  Situacion
# 0  ANTONIO     GARCIA         73   Aprobado   Aprobado
# 1   MANUEL  FERNANDEZ         19  Reprobado  Reprobado
# 2     JOSE   GONZALEZ         38  Reprobado  Reprobado
# 3    DAVID      PEREZ         14  Reprobado  Reprobado
# 4     JUAN      LOPEZ         99   Aprobado   Aprobado

# %%
#aggregate agg
#contar aprobados y reprobados
calificaciones.groupby('situacion').agg(['count','mean','std']).round(1)
# Out:
# <ipython-input-21-8e574b359646>:3: FutureWarning: ['Nombre', 'Apellido', 'Situacion'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   calificaciones.groupby('situacion').agg(['count','mean','std']).round(1)
#           CaliFinal
#               count  mean   std
# situacion
# Aprobado         10  90.1  10.0
# Reprobado        18  30.8  21.6

# %% [markdown]
# ##Libreria Matplolib
# es el graficador estandar de python

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
personas =[ 1, 2, 3, 4]
edades =[ 28, 21, 30, 27]

# %%
###Hacer grafica de dispersion
plt.plot(personas,edades)
plt.show()

# %%
###Hacer grafica de dispersion
plt.scatter(personas,edades, color=['blue','red','yellow', 'pink'])
plt.xlabel('Personas')
plt.ylabel('Edad (años)')
plt.title('EDADES DE 4 DESCONOCIDOS')
plt.show()

# %%
###Hacer grafica de barras
plt.bar(personas,edades)
plt.show()
